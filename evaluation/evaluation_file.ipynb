# %%
import os
import json
import argparse

from constants import RANGE_KEY, READING_KEY

# %%
with open('/home/mreitsma/test_images/true_readings_old.json', 'r') as file:
    old_dict = json.load(file)

with open('/home/mreitsma/test_images/true_readings.json', 'r') as file:
    new_dict = json.load(file)

for key in old_dict:
    new_dict[key][READING_KEY] = old_dict[key][READING_KEY] 
    new_dict[key][RANGE_KEY] = old_dict[key][RANGE_KEY] 

new_json = json.dumps(new_dict, indent=4)
with open('/home/mreitsma/test_images/true_readings.json', "w") as outfile:
    outfile.write(new_json)
